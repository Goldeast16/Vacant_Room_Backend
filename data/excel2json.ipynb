# %%
import pandas as pd
import os

# %%
# 엑셀 파일 경로
excel_path = "raw_data/cau_2025_timetable.xlsx"

# 엑셀 로드 (첫 시트 기준)
excel_df = pd.read_excel(excel_path, engine="openpyxl")

# DataFrame 확인
excel_df.head()
# Out:
#        대학 개설학과  학년  과정  이수구분   과목번호-분반             과목명 학점-시간          담당교수  \
# 0  대학(전체)  NaN   3  학사  자유선택  54943-01  안전 및 조직관리 사례연구   3-6  학군단(R.O.T.C)
# 1  대학(전체)  NaN   3  학사  자유선택  54943-02  안전 및 조직관리 사례연구   3-6  학군단(R.O.T.C)
# 2  대학(전체)  NaN   4  학사  자유선택  54945-01      조직리더십 사례연구   3-6  학군단(R.O.T.C)
# 3  대학(전체)  NaN   4  학사  자유선택  54945-02      조직리더십 사례연구   3-6  학군단(R.O.T.C)
# 4  대학(전체)  NaN  전체  학사    교양  49950-01             ACT   2-2           최문정
#
#     폐강                                         강의시간 유연학기                 비고  \
# 0  NaN        화0,1,2, 목0,1,2 / 305관 216호 <3학년 훈육관실>  NaN            R.O.T.C
# 1  NaN  화10,11,12, 목10,11,12 / 305관 216호 <3학년 훈육관실>  NaN            R.O.T.C
# 2  NaN        화0,1,2, 목0,1,2 / 305관 215호 <4학년 훈육관실>  NaN            R.O.T.C
# 3  NaN  화10,11,12, 목10,11,12 / 305관 215호 <4학년 훈육관실>  NaN            R.O.T.C
# 4  NaN                       월1,2 / 310관 718호 <강의실>  NaN  공통교양 2학년 이상 수강 가능
#
#   수업유형
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# 1. 과목번호, 과목명, 담당교수, 폐강, 강의시간만 남기고 제거
columns_to_keep = ["과목번호-분반", "과목명", "담당교수", "폐강", "강의시간"]
excel_df = excel_df[columns_to_keep]
excel_df.head()
# Out:
#     과목번호-분반             과목명          담당교수   폐강  \
# 0  54943-01  안전 및 조직관리 사례연구  학군단(R.O.T.C)  NaN
# 1  54943-02  안전 및 조직관리 사례연구  학군단(R.O.T.C)  NaN
# 2  54945-01      조직리더십 사례연구  학군단(R.O.T.C)  NaN
# 3  54945-02      조직리더십 사례연구  학군단(R.O.T.C)  NaN
# 4  49950-01             ACT           최문정  NaN
#
#                                           강의시간
# 0        화0,1,2, 목0,1,2 / 305관 216호 <3학년 훈육관실>
# 1  화10,11,12, 목10,11,12 / 305관 216호 <3학년 훈육관실>
# 2        화0,1,2, 목0,1,2 / 305관 215호 <4학년 훈육관실>
# 3  화10,11,12, 목10,11,12 / 305관 215호 <4학년 훈육관실>
# 4                       월1,2 / 310관 718호 <강의실>

# %%
# 1. 폐강 열이 NaN이 아닌 행 제거
excel_df = excel_df[excel_df["폐강"].isna()]

# 2. 폐강 열 제거
excel_df = excel_df.drop(columns=["폐강"])
excel_df.head()
# Out:
#     과목번호-분반             과목명          담당교수  \
# 0  54943-01  안전 및 조직관리 사례연구  학군단(R.O.T.C)
# 1  54943-02  안전 및 조직관리 사례연구  학군단(R.O.T.C)
# 2  54945-01      조직리더십 사례연구  학군단(R.O.T.C)
# 3  54945-02      조직리더십 사례연구  학군단(R.O.T.C)
# 4  49950-01             ACT           최문정
#
#                                           강의시간
# 0        화0,1,2, 목0,1,2 / 305관 216호 <3학년 훈육관실>
# 1  화10,11,12, 목10,11,12 / 305관 216호 <3학년 훈육관실>
# 2        화0,1,2, 목0,1,2 / 305관 215호 <4학년 훈육관실>
# 3  화10,11,12, 목10,11,12 / 305관 215호 <4학년 훈육관실>
# 4                       월1,2 / 310관 718호 <강의실>

# %%
def convert_period_to_time(period_num: int) -> str:
    # 0교시: 8시 시작, 그 이후는 9시부터 시작
    base_hour = 8 if period_num == 0 else 9 + (period_num - 1)
    start = f"{base_hour:02d}:00"
    end = f"{base_hour + 1:02d}:00"
    return f"{start}~{end}"

import re

def parse_schedule(schedule_str: str):
    if pd.isna(schedule_str):
        return None, None, None

    # 시간 정보 추출

    # 예: '월10 / 310관 802호' 또는 '월(10:30~11:45) / 수10 / 303관 802호'
    parts = schedule_str.split('/')
    time_parts = []
    room_part = None

    for part in parts:
        part = part.strip()

        # 교시 형식 예: 월0, 수3 등
        match_period = re.match(r"([월화수목금토일])(\d+)", part)
        if match_period:
            day = match_period.group(1)
            period = int(match_period.group(2))
            time_range = convert_period_to_time(period)
            time_parts.append(f"{day}({time_range})")
            continue

        # 이미 시간으로 되어 있으면 그대로 추가
        match_time = re.match(r"([월화수목금토일])\(.+\)", part)
        if match_time:
            time_parts.append(part)
            continue

        # 강의실 정보로 간주
        if re.search(r"\d+관.*\d+호", part):
            room_part = part

    # 건물번호, 강의실 분리
    building = None
    classroom = None
    if room_part:
        match_room = re.match(r"(\d+관).*?(\d+-?\d*호)", room_part)
        if match_room:
            building = match_room.group(1)
            classroom = match_room.group(2)

    return " / ".join(time_parts), building, classroom

def split_time_info(time_str):
    if pd.isna(time_str):
        return None, None

    days = []
    times = []

    # 예: 월(10:30~11:45)
    parts = [p.strip() for p in time_str.split('/')]

    for part in parts:
        match = re.match(r"([월화수목금토일])\((\d{2}:\d{2}~\d{2}:\d{2})\)", part)
        if match:
            days.append(match.group(1))
            times.append(match.group(2))

    return days, times


# 강의시간, 건물번호, 강의실 파싱해서 새 컬럼으로 추가
excel_df[["강의시간_24시", "건물번호", "강의실"]] = excel_df["강의시간"].apply(
    lambda x: pd.Series(parse_schedule(x))
)

excel_df[["강의요일", "강의시간_리스트"]] = excel_df["강의시간_24시"].apply(
    lambda x: pd.Series(split_time_info(x))
)

excel_df = excel_df.drop(columns=["강의시간", "강의시간_24시"])

# 확인
excel_df.head()
# Out:
#     과목번호-분반             과목명          담당교수  건물번호   강의실 강의요일       강의시간_리스트
# 0  54943-01  안전 및 조직관리 사례연구  학군단(R.O.T.C)  305관  216호  [화]  [08:00~09:00]
# 1  54943-02  안전 및 조직관리 사례연구  학군단(R.O.T.C)  305관  216호  [화]  [18:00~19:00]
# 2  54945-01      조직리더십 사례연구  학군단(R.O.T.C)  305관  215호  [화]  [08:00~09:00]
# 3  54945-02      조직리더십 사례연구  학군단(R.O.T.C)  305관  215호  [화]  [18:00~19:00]
# 4  49950-01             ACT           최문정  310관  718호  [월]  [09:00~10:00]

# %%
print(excel_df[excel_df["강의시간_리스트"].isnull()])
# Out:
#        과목번호-분반                  과목명     담당교수  건물번호   강의실  강의요일 강의시간_리스트
# 318   57104-01            공공기관NCS분석   인재개발센터  None  None  None     None
# 2373  58469-01               기초나노역학      유재형  None  None  None     None
# 2374  58583-01             나노소재물리화학      남인호  None  None  None     None
# 2375  58584-01               융합양자개론      이창연  None  None  None     None
# 2389  58470-01                 제조공학      김석민  None  None  None     None
# 2390  58602-01               위상최적설계      김영규  None  None  None     None
# 2391  58604-01               바이오프린팅      배진혜  None  None  None     None
# 2393  58573-01              첨단무기신소재  남인호 박승근  None  None  None     None
# 2394  58467-01              첨단신소재입문      박승근  None  None  None     None
# 2395  58466-01            첨단신소재재료과학      김영규  None  None  None     None
# 2396  58580-01            복합재료및생체응용  장승환 강은아  None  None  None     None
# 2397  58471-01               이차전지재료  장해성 남인호  None  None  None     None
# 2398  58579-01               전자세라믹스      백태종  None  None  None     None
# 2399  58468-01            첨단철강및국방소재      진영호  None  None  None     None
# 2400  58609-01                기초물리학      이근중  None  None  None     None
# 2401  58608-01                기초미적분      NaN  None  None  None     None
# 2402  58464-01            기초통계및머신러닝  이수영 김석민  None  None  None     None
# 2403  58610-01                 기초화학      홍종인  None  None  None     None
# 2404  58461-01     생활속의첨단소재나노적층공정기술      김영규  None  None  None     None
# 2451  50129-01    의과학자를 위한 실험방법론(2)      NaN  None  None  None     None
# 2452  50130-01  의과학자를 위한 실험방법론실습(2)      NaN  None  None  None     None
# 2453  50130-02  의과학자를 위한 실험방법론실습(2)      NaN  None  None  None     None
# 2454  56831-01     의사와 사회 (4): 행동과학      NaN  None  None  None     None
# 2455  58141-01                의생명과학      NaN  None  None  None     None
# 2456  50135-01              의학영어(2)      NaN  None  None  None     None
# 2457  53865-01                   감염      NaN  None  None  None     None
# 2458  51143-01              기본근골격계학      NaN  None  None  None     None
# 2459  51122-01                 내분비학      NaN  None  None  None     None
# 2460  51124-01          문제중심학습(1-2)      NaN  None  None  None     None
# 2461  51124-02          문제중심학습(1-2)      NaN  None  None  None     None
# 2462  51124-03          문제중심학습(1-2)      NaN  None  None  None     None
# 2463  51124-04          문제중심학습(1-2)      NaN  None  None  None     None

# %%
# zip 요일과 시간 리스트 → 튜플 목록
excel_df["temp"] = excel_df.apply(
    lambda row: list(zip(row["강의요일"], row["강의시간_리스트"])), axis=1
)

# explode
df_exploded = excel_df.explode("temp")

# 튜플만 남기기
df_exploded = df_exploded[df_exploded["temp"].apply(lambda x: isinstance(x, tuple) and len(x) == 2)]

# 튜플 분리
df_exploded[["요일", "시간"]] = pd.DataFrame(df_exploded["temp"].tolist(), index=df_exploded.index)
df_exploded = df_exploded.drop(columns=["temp", "강의요일", "강의시간_리스트"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # zip 요일과 시간 리스트 → 튜플 목록
# ----> 2 excel_df["temp"] = excel_df.apply(
#       3     lambda row: list(zip(row["강의요일"], row["강의시간_리스트"])), axis=1
#       4 )
#       6 # explode
#       7 df_exploded = excel_df.explode("temp")
#
# File D:\Project\CAS_Summer_Backend\.venv\Lib\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)  10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File D:\Project\CAS_Summer_Backend\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File D:\Project\CAS_Summer_Backend\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File D:\Project\CAS_Summer_Backend\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[6], line 3, in <lambda>(row)
#       1 # zip 요일과 시간 리스트 → 튜플 목록
#       2 excel_df["temp"] = excel_df.apply(
# ----> 3     lambda row: list(zip(row["강의요일"], row["강의시간_리스트"])), axis=1
#       4 )
#       6 # explode
#       7 df_exploded = excel_df.explode("temp")
#
# TypeError: 'NoneType' object is not iterable

# %%
df_exploded[["시작시간", "종료시간"]] = df_exploded["시간"].str.split("~", expand=True)
df_exploded = df_exploded.drop(columns=["시간"])

# %%
df_exploded = df_exploded.rename(columns={
    "건물번호": "building",
    "강의실": "room",
    "요일": "day",
    "시작시간": "start_time",
    "종료시간": "end_time",
    "과목번호-분반": "course_id",
    "과목명": "course_name",
    "담당교수": "professor"
})

# %%
df_exploded = df_exploded[
    ["building", "room", "day", "start_time", "end_time", "course_id", "course_name", "professor"]
]

# %%
# building에서 숫자만 추출 (예: "310관" → "310")
df_exploded["building"] = df_exploded["building"].apply(
    lambda x: re.search(r"\d+", str(x)).group() if pd.notna(x) else None
)

# room에서도 숫자만 추출 (예: "415호" 또는 "802-1호" → "415", "802-1")
df_exploded["room"] = df_exploded["room"].apply(
    lambda x: re.search(r"\d+(?:-\d+)?", str(x)).group() if pd.notna(x) else None
)

# %%
day_map = {
    "월": "monday",
    "화": "tuesday",
    "수": "wednesday",
    "목": "thursday",
    "금": "friday",
    "토": "saturday",
    "일": "sunday"
}

df_exploded["day"] = df_exploded["day"].map(day_map)

# %%
df_exploded = df_exploded.dropna(subset=["building", "room"])

# %%
df_exploded["building"] = df_exploded["building"].astype(int)

# %%
df_exploded.tail(20)
# Out:
#     building room        day start_time end_time course_id       course_name  \
# 82       310  802  wednesday      10:30    11:45  56107-01  동태적 경제이론 (영어A강의)
# 83       310  921     friday      15:00    16:00  10235-02             산업조직론
# 86       310  612     monday      15:00    16:15  54461-02           응용계량경제학
# 86       310  612  wednesday      15:00    16:15  54461-02           응용계량경제학
# 87       310  927     monday      13:30    14:45  24658-01             화폐금융론
# 87       310  927  wednesday      13:30    14:45  24658-01             화폐금융론
# 88       310  311    tuesday      13:30    14:45  24658-02             화폐금융론
# 88       310  311   thursday      13:30    14:45  24658-02             화폐금융론
# 89       310  505   thursday      12:00    13:00  24658-03     화폐금융론 (영어A강의)
# 90       310  921     monday      09:00    10:15  01452-01     경제정책론 (영어A강의)
# 90       310  921  wednesday      09:00    10:15  01452-01     경제정책론 (영어A강의)
# 91       310  920    tuesday      10:30    11:45  51442-01          유통서비스경제론
# 91       310  920   thursday      10:30    11:45  51442-01          유통서비스경제론
# 92       310  818     friday      15:00    16:00  51442-02          유통서비스경제론
# 93       310  802    tuesday      10:30    11:45  38944-01           파생금융상품론
# 93       310  802   thursday      10:30    11:45  38944-01           파생금융상품론
# 94       310  802     monday      12:00    13:00  38944-02           파생금융상품론
# 95       310  802    tuesday      16:30    17:45  56109-01             행동경제학
# 95       310  802   thursday      16:30    17:45  56109-01             행동경제학
# 96       310  412     friday      12:00    13:00  56109-02             행동경제학
#
#    professor
# 82       문지웅
# 83       김형진
# 86       NaN
# 86       NaN
# 87       송원호
# 87       송원호
# 88       김태진
# 88       김태진
# 89       구세범
# 90        고선
# 90        고선
# 91       이정희
# 91       이정희
# 92       신영호
# 93       서상원
# 93       서상원
# 94       NaN
# 95       진현정
# 95       진현정
# 96       NaN

# %%
json_data = df_exploded.to_dict(orient="records")

save_dir = "converted_data"
os.makedirs(save_dir, exist_ok=True)

import json

save_path = os.path.join(save_dir, "room_schedule.json")

with open(save_path, "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=2)

print(f"✅ JSON 저장 완료: {save_path}")
# Out:
# ✅ JSON 저장 완료: converted_data\room_schedule.json
